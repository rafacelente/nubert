# %% [markdown]
# # Exploratory Analysis - Nubank AI Core Transaction Dataset Interview Project
#
# This notebook is a collection of exploratory analyses on the dataset provided for the Nubank AI Core Transaction Dataset Interview Project. The content here is not supposed to be presentation-grade, but more of a stream-of-consciousness type of exploration of the dataset.

# %%
import pandas as pd
from pprint import pprint

# %% [markdown]
# ## Dataset

# %%
df = pd.read_csv('raw_dataset.csv')
# Out:
# /tmp/ipykernel_39/1635338934.py:1: DtypeWarning: Columns (12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('raw_dataset.csv')

# %%
df.head()
# Out:
#    Year-Month  Agency Number                Agency Name Cardholder Last Name  \
# 0      201307           1000  OKLAHOMA STATE UNIVERSITY                Mason
# 1      201307           1000  OKLAHOMA STATE UNIVERSITY                Mason
# 2      201307           1000  OKLAHOMA STATE UNIVERSITY               Massey
# 3      201307           1000  OKLAHOMA STATE UNIVERSITY               Massey
# 4      201307           1000  OKLAHOMA STATE UNIVERSITY        Mauro-Herrera
#
#   Cardholder First Initial  Amount          Vendor        Transaction Date  \
# 0                        C     890           NACAS  07/30/2013 12:00:00 AM
# 1                        C  368.96  SHERATON HOTEL  07/30/2013 12:00:00 AM
# 2                        J  165.82  SEARS.COM 9300  07/29/2013 12:00:00 AM
# 3                        T   96.39  WAL-MART #0137  07/30/2013 12:00:00 AM
# 4                        M  125.96  STAPLES DIRECT  07/30/2013 12:00:00 AM
#
#               Posted Date                       Merchant Category Code (MCC)  \
# 0  07/31/2013 12:00:00 AM        CHARITABLE AND SOCIAL SERVICE ORGANIZATIONS
# 1  07/31/2013 12:00:00 AM                                           SHERATON
# 2  07/31/2013 12:00:00 AM  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 3  07/31/2013 12:00:00 AM                    GROCERY STORES,AND SUPERMARKETS
# 4  07/31/2013 12:00:00 AM  STATIONERY, OFFICE SUPPLIES, PRINTING AND WRIT...
#
#   Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# 0         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN

# %%
df.columns
# Out:
# Index(['Year-Month', 'Agency Number', 'Agency Name', 'Cardholder Last Name',
#        'Cardholder First Initial', 'Amount', 'Vendor', 'Transaction Date',
#        'Posted Date', 'Merchant Category Code (MCC)', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %% [markdown]
# My first thought here is that we don't have much to work with. The fields that we have don't have a clear classification/regression signal, so we might have to get creative. However, some categories such as MCC, Vendor and Amount may have some cool information to extract.
#
# Moreover, there seems to be 5 columns that are pretty vague (10,11,12,13,14) and have no information on them. Let's take a look at them first so we can figure out if we can discard them right away.

# %%
def is_date(s):
    if pd.isna(s):
            return False
    try:
        pd.to_datetime(s)
        return True
    except ValueError:
        return False

def print_column_information(df: pd.DataFrame, column_name: str):
    sized = df.groupby(column_name).size()
    column_size = len(sized)
    n_dates = df[df[column_name].apply(is_date) == True].shape[0]
    n_empty = sum([x == '' for x in df[column_name]])
    n_nan = sum([pd.isna(x) for x in df[column_name]])
    uniques = sized.index

    print("-"*50)
    print(f'Column: {column_name}')
    print(f"Column total size: {len(df[column_name])}")
    print(f"Column non-nan size: {len(df[column_name].dropna())}")
    print(f'Column unique size: {column_size}')
    print(f'Number of dates: {n_dates}')
    print(f'Number of empty strings: {n_empty}')
    print(f'Number of NaN: {n_nan}')
    print(f'Unique values: {uniques}')
    print("-"*50)

    

print_column_information(df, 'Unnamed: 10')
print_column_information(df, 'Unnamed: 11')
print_column_information(df, 'Unnamed: 12')
print_column_information(df, 'Unnamed: 13')
print_column_information(df, 'Unnamed: 14')
# Out:
# --------------------------------------------------
# Column: Unnamed: 10
# Column total size: 442458
# Column non-nan size: 275
# Column unique size: 103
# Number of dates: 146
# Number of empty strings: 0
# Number of NaN: 442183
# Unique values: Index(['01/03/2014 12:00:00 AM', '01/10/2014 12:00:00 AM',
#        '01/13/2014 12:00:00 AM', '01/14/2014 12:00:00 AM',
#        '01/15/2014 12:00:00 AM', '01/20/2014 12:00:00 AM',
#        '01/22/2014 12:00:00 AM', '02/03/2014 12:00:00 AM',
#        '02/10/2014 12:00:00 AM', '02/11/2014 12:00:00 AM',
#        ...
#        'COMPUTERS, COMPUTER PERIPHERAL EQUIPMENT, SOFTWARE',
#        'CONTINUITY/SUBSCRIPTION MERCHANTS',
#        'DENTAL/LABORATORY/MEDICAL/OPHTHALMIC HOSP EQIP AND SUP.',
#        'DMI  DELL K-12/GOVT', 'ELECTRICAL PARTS AND EQUIPMENT',
#        'ELECTRONICS STORES', 'INDUSTRIAL SUPPLIES NOT ELSEWHERE CLASSIFIED',
#        'MISCELLANEOUS PUBLISHING AND PRINTING SERVICES',
#        'PLUMBING AND HEATING EQUIPMENT AND SUPPLIES',
#        'STATIONERY, OFFICE SUPPLIES, PRINTING AND WRITING PAPER'],
#       dtype='object', name='Unnamed: 10', length=103)
# --------------------------------------------------
# --------------------------------------------------
# Column: Unnamed: 11
# Column total size: 442458
# Column non-nan size: 148
# Column unique size: 7
# Number of dates: 1
# Number of empty strings: 0
# Number of NaN: 442310
# Unique values: Index(['06/19/2014 12:00:00 AM', 'BUSINESS SERVICES NOT ELSEWHERE CLASSIFIED',
#        'COMMERCIAL EQUIPMENT, NOT ELSEWHERE CLASSIFIED',
#        'CONTINUITY/SUBSCRIPTION MERCHANTS', 'ELECTRICAL PARTS AND EQUIPMENT',
#        'INDUSTRIAL SUPPLIES NOT ELSEWHERE CLASSIFIED', 'TEQUIPMENT.NET'],
#       dtype='object', name='Unnamed: 11')
# --------------------------------------------------
# --------------------------------------------------
# Column: Unnamed: 12
# Column total size: 442458
# Column non-nan size: 2
# Column unique size: 2
# Number of dates: 2
# Number of empty strings: 0
# Number of NaN: 442456
# Unique values: Index(['06/19/2014 12:00:00 AM', '11/03/2013 12:00:00 AM'], dtype='object', name='Unnamed: 12')
# --------------------------------------------------
# --------------------------------------------------
# Column: Unnamed: 13
# Column total size: 442458
# Column non-nan size: 2
# Column unique size: 2
# Number of dates: 1
# Number of empty strings: 0
# Number of NaN: 442456
# Unique values: Index(['11/04/2013 12:00:00 AM', 'COMPUTERS, COMPUTER PERIPHERAL EQUIPMENT, SOFTWARE'], dtype='object', name='Unnamed: 13')
# --------------------------------------------------
# --------------------------------------------------
# Column: Unnamed: 14
# Column total size: 442458
# Column non-nan size: 1
# Column unique size: 1
# Number of dates: 0
# Number of empty strings: 0
# Number of NaN: 442457
# Unique values: Index(['ELECTRICAL PARTS AND EQUIPMENT'], dtype='object', name='Unnamed: 14')
# --------------------------------------------------

# %%
df[pd.isna(df['Unnamed: 14']) == False]
# Out:
#         Year-Month  Agency Number             Agency Name  \
# 190452      201311          76000  UNIVERSITY OF OKLAHOMA
#
#        Cardholder Last Name Cardholder First Initial    Amount        Vendor  \
# 190452              SADEGHI                        K  CLEANING  0.8mm NOZZLE
#
#        Transaction Date Posted Date Merchant Category Code (MCC) Unnamed: 10  \
# 190452         EACH|PIN    CLEANING                        1.0mm      212.87
#
#            Unnamed: 11             Unnamed: 12             Unnamed: 13  \
# 190452  TEQUIPMENT.NET  11/03/2013 12:00:00 AM  11/04/2013 12:00:00 AM
#
#                            Unnamed: 14
# 190452  ELECTRICAL PARTS AND EQUIPMENT

# %% [markdown]
# ## Cleaning

# %% [markdown]
# It seems that these unnamed columns contain values that are badly parsed (example above). It seems that the input may have been mixed up and it requires manual clean-up. To not accidently parse bad values, I'll opt to simply remove these badly parsed values from the dataset.

# %%
df[pd.isna(df['Unnamed: 13']) == False]
# Out:
#         Year-Month  Agency Number                 Agency Name  \
# 190452      201311          76000      UNIVERSITY OF OKLAHOMA
# 398823      201406          34000  STATE DEPARTMENT OF HEALTH
#
#        Cardholder Last Name Cardholder First Initial    Amount        Vendor  \
# 190452              SADEGHI                        K  CLEANING  0.8mm NOZZLE
# 398823               Farris                        S  MMag Duo       USB/HID
#
#        Transaction Date Posted Date Merchant Category Code (MCC)  \
# 190452         EACH|PIN    CLEANING                        1.0mm
# 398823               3T      Bl PCE                        54.14
#
#                 Unnamed: 10             Unnamed: 11             Unnamed: 12  \
# 190452               212.87          TEQUIPMENT.NET  11/03/2013 12:00:00 AM
# 398823  DMI  DELL K-12/GOVT  06/19/2014 12:00:00 AM  06/19/2014 12:00:00 AM
#
#                                               Unnamed: 13  \
# 190452                             11/04/2013 12:00:00 AM
# 398823  COMPUTERS, COMPUTER PERIPHERAL EQUIPMENT, SOFT...
#
#                            Unnamed: 14
# 190452  ELECTRICAL PARTS AND EQUIPMENT
# 398823                             NaN

# %%
df[pd.isna(df['Unnamed: 12']) == False]
# Out:
#         Year-Month  Agency Number                 Agency Name  \
# 190452      201311          76000      UNIVERSITY OF OKLAHOMA
# 398823      201406          34000  STATE DEPARTMENT OF HEALTH
#
#        Cardholder Last Name Cardholder First Initial    Amount        Vendor  \
# 190452              SADEGHI                        K  CLEANING  0.8mm NOZZLE
# 398823               Farris                        S  MMag Duo       USB/HID
#
#        Transaction Date Posted Date Merchant Category Code (MCC)  \
# 190452         EACH|PIN    CLEANING                        1.0mm
# 398823               3T      Bl PCE                        54.14
#
#                 Unnamed: 10             Unnamed: 11             Unnamed: 12  \
# 190452               212.87          TEQUIPMENT.NET  11/03/2013 12:00:00 AM
# 398823  DMI  DELL K-12/GOVT  06/19/2014 12:00:00 AM  06/19/2014 12:00:00 AM
#
#                                               Unnamed: 13  \
# 190452                             11/04/2013 12:00:00 AM
# 398823  COMPUTERS, COMPUTER PERIPHERAL EQUIPMENT, SOFT...
#
#                            Unnamed: 14
# 190452  ELECTRICAL PARTS AND EQUIPMENT
# 398823                             NaN

# %%
df[pd.isna(df['Unnamed: 11']) == False]
# Out:
#         Year-Month  Agency Number                            Agency Name  \
# 3247        201307           1000              OKLAHOMA STATE UNIVERSITY
# 7461        201307           1000              OKLAHOMA STATE UNIVERSITY
# 7719        201307           1000              OKLAHOMA STATE UNIVERSITY
# 14038       201308           1000              OKLAHOMA STATE UNIVERSITY
# 18697       201308           1000              OKLAHOMA STATE UNIVERSITY
# ...            ...            ...                                    ...
# 424586      201406          76000                 UNIVERSITY OF OKLAHOMA
# 426287      201406          76000                 UNIVERSITY OF OKLAHOMA
# 426404      201406          76000                 UNIVERSITY OF OKLAHOMA
# 428992      201405          77000  UNIV. OF OKLA. HEALTH SCIENCES CENTER
# 434614      201406          77000  UNIV. OF OKLA. HEALTH SCIENCES CENTER
#
#        Cardholder Last Name Cardholder First Initial  \
# 3247                  Sisco                        K
# 7461                 Hudson                        J
# 7719                  Kiner                        K
# 14038                 Sisco                        K
# 18697                 Kiner                        K
# ...                     ...                      ...
# 424586                DAVIS                        M
# 426287               O'DELL                        D
# 426404             BRADFORD                        L
# 428992              COLBERT                        L
# 434614              COLBERT                        L
#
#                                 Amount       Vendor Transaction Date  \
# 3247    0 - 500 Co EACH|MyLibrary Plus          MyL               25
# 7461    2501 - 500 EACH|MyLibrary Plus          MyL               55
# 7719    0 - 500 Co EACH|MyLibrary Plus          MyL               20
# 14038   0 - 500 Co EACH|MyLibrary Plus          MyL               25
# 18697   0 - 500 Co EACH|MyLibrary Plus          MyL               20
# ...                                ...          ...              ...
# 424586          10001 - 25 EACH|Survey  Free Monthl              195
# 426287          10001 - 25 EACH|Survey  Free Monthl              195
# 426404       2501 - 500 EACH|EventSpot      11 - 20              125
# 428992  501 - 2500 EACH|MyLibrary Plus          MyL               35
# 434614  501 - 2500 EACH|MyLibrary Plus          MyL               35
#
#                     Posted Date Merchant Category Code (MCC)  \
# 3247    CTC CONSTANTCONTACT.COM       07/09/2013 12:00:00 AM
# 7461    CTC CONSTANTCONTACT.COM       07/19/2013 12:00:00 AM
# 7719    CTC CONSTANTCONTACT.COM       07/21/2013 12:00:00 AM
# 14038   CTC CONSTANTCONTACT.COM       08/09/2013 12:00:00 AM
# 18697   CTC CONSTANTCONTACT.COM       08/21/2013 12:00:00 AM
# ...                         ...                          ...
# 424586  CTC CONSTANTCONTACT.COM       06/11/2014 12:00:00 AM
# 426287  CTC CONSTANTCONTACT.COM       06/02/2014 12:00:00 AM
# 426404  CTC CONSTANTCONTACT.COM       06/02/2014 12:00:00 AM
# 428992  CTC CONSTANTCONTACT.COM       05/10/2014 12:00:00 AM
# 434614  CTC CONSTANTCONTACT.COM       06/10/2014 12:00:00 AM
#
#                    Unnamed: 10                        Unnamed: 11 Unnamed: 12  \
# 3247    07/10/2013 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS         NaN
# 7461    07/22/2013 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS         NaN
# 7719    07/22/2013 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS         NaN
# 14038   08/12/2013 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS         NaN
# 18697   08/22/2013 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS         NaN
# ...                        ...                                ...         ...
# 424586  06/12/2014 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS         NaN
# 426287  06/03/2014 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS         NaN
# 426404  06/03/2014 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS         NaN
# 428992  05/12/2014 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS         NaN
# 434614  06/11/2014 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS         NaN
#
#        Unnamed: 13 Unnamed: 14
# 3247           NaN         NaN
# 7461           NaN         NaN
# 7719           NaN         NaN
# 14038          NaN         NaN
# 18697          NaN         NaN
# ...            ...         ...
# 424586         NaN         NaN
# 426287         NaN         NaN
# 426404         NaN         NaN
# 428992         NaN         NaN
# 434614         NaN         NaN
#
# [148 rows x 15 columns]

# %%
df[pd.isna(df['Unnamed: 10']) == False]
# Out:
#         Year-Month  Agency Number                            Agency Name  \
# 473         201307           1000              OKLAHOMA STATE UNIVERSITY
# 3247        201307           1000              OKLAHOMA STATE UNIVERSITY
# 5199        201307           1000              OKLAHOMA STATE UNIVERSITY
# 5280        201307           1000              OKLAHOMA STATE UNIVERSITY
# 7461        201307           1000              OKLAHOMA STATE UNIVERSITY
# ...            ...            ...                                    ...
# 434614      201406          77000  UNIV. OF OKLA. HEALTH SCIENCES CENTER
# 440606      201405          98000                  GRAND RIVER DAM AUTH.
# 440608      201405          98000                  GRAND RIVER DAM AUTH.
# 441920      201406          98000                  GRAND RIVER DAM AUTH.
# 441923      201406          98000                  GRAND RIVER DAM AUTH.
#
#        Cardholder Last Name Cardholder First Initial  \
# 473                  Livsey                        K
# 3247                  Sisco                        K
# 5199               Vandiver                        C
# 5280                 Leslie                        C
# 7461                 Hudson                        J
# ...                     ...                      ...
# 434614              COLBERT                        L
# 440606             Ragsdale                        M
# 440608             Ragsdale                        M
# 441920             Ragsdale                        M
# 441923             Ragsdale                        M
#
#                                 Amount Vendor         Transaction Date  \
# 473                    0 - 500 Co EACH     15  CTC CONSTANTCONTACT.COM
# 3247    0 - 500 Co EACH|MyLibrary Plus    MyL                       25
# 5199              0 - 1 Published EACH     20  CTC CONSTANTCONTACT.COM
# 5280                   501 - 2500 EACH     30  CTC CONSTANTCONTACT.COM
# 7461    2501 - 500 EACH|MyLibrary Plus    MyL                       55
# ...                                ...    ...                      ...
# 434614  501 - 2500 EACH|MyLibrary Plus    MyL                       35
# 440606                         CABL EA  264.8            STUART C IRBY
# 440608                              BR  585.5            STUART C IRBY
# 441920                          BRZ EA  443.5            STUART C IRBY
# 441923                             ROU   79.5            STUART C IRBY
#
#                     Posted Date Merchant Category Code (MCC)  \
# 473      07/26/2013 12:00:00 AM       07/29/2013 12:00:00 AM
# 3247    CTC CONSTANTCONTACT.COM       07/09/2013 12:00:00 AM
# 5199     07/17/2013 12:00:00 AM       07/18/2013 12:00:00 AM
# 5280     07/15/2013 12:00:00 AM       07/16/2013 12:00:00 AM
# 7461    CTC CONSTANTCONTACT.COM       07/19/2013 12:00:00 AM
# ...                         ...                          ...
# 434614  CTC CONSTANTCONTACT.COM       06/10/2014 12:00:00 AM
# 440606   05/19/2014 12:00:00 AM       05/20/2014 12:00:00 AM
# 440608   05/19/2014 12:00:00 AM       05/20/2014 12:00:00 AM
# 441920   06/09/2014 12:00:00 AM       06/10/2014 12:00:00 AM
# 441923   06/09/2014 12:00:00 AM       06/10/2014 12:00:00 AM
#
#                               Unnamed: 10                        Unnamed: 11  \
# 473     CONTINUITY/SUBSCRIPTION MERCHANTS                                NaN
# 3247               07/10/2013 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS
# 5199    CONTINUITY/SUBSCRIPTION MERCHANTS                                NaN
# 5280    CONTINUITY/SUBSCRIPTION MERCHANTS                                NaN
# 7461               07/22/2013 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS
# ...                                   ...                                ...
# 434614             06/11/2014 12:00:00 AM  CONTINUITY/SUBSCRIPTION MERCHANTS
# 440606     ELECTRICAL PARTS AND EQUIPMENT                                NaN
# 440608     ELECTRICAL PARTS AND EQUIPMENT                                NaN
# 441920     ELECTRICAL PARTS AND EQUIPMENT                                NaN
# 441923     ELECTRICAL PARTS AND EQUIPMENT                                NaN
#
#        Unnamed: 12 Unnamed: 13 Unnamed: 14
# 473            NaN         NaN         NaN
# 3247           NaN         NaN         NaN
# 5199           NaN         NaN         NaN
# 5280           NaN         NaN         NaN
# 7461           NaN         NaN         NaN
# ...            ...         ...         ...
# 434614         NaN         NaN         NaN
# 440606         NaN         NaN         NaN
# 440608         NaN         NaN         NaN
# 441920         NaN         NaN         NaN
# 441923         NaN         NaN         NaN
#
# [275 rows x 15 columns]

# %%
before_len = len(df)
df = df[pd.isna(df['Unnamed: 10']) == True]
df = df[pd.isna(df['Unnamed: 11']) == True]
df = df[pd.isna(df['Unnamed: 12']) == True]
df = df[pd.isna(df['Unnamed: 13']) == True]
df = df[pd.isna(df['Unnamed: 14']) == True]
after_len = len(df)
df.drop(columns=['Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14'], inplace=True)
print(f"Removed {before_len - after_len} rows")
# Out:
# Removed 275 rows

# %%
df
# Out:
#         Year-Month  Agency Number                Agency Name  \
# 0           201307           1000  OKLAHOMA STATE UNIVERSITY
# 1           201307           1000  OKLAHOMA STATE UNIVERSITY
# 2           201307           1000  OKLAHOMA STATE UNIVERSITY
# 3           201307           1000  OKLAHOMA STATE UNIVERSITY
# 4           201307           1000  OKLAHOMA STATE UNIVERSITY
# ...            ...            ...                        ...
# 442453      201406          98000      GRAND RIVER DAM AUTH.
# 442454      201406          98000      GRAND RIVER DAM AUTH.
# 442455      201406          98000      GRAND RIVER DAM AUTH.
# 442456      201406          98000      GRAND RIVER DAM AUTH.
# 442457      201406          98000      GRAND RIVER DAM AUTH.
#
#        Cardholder Last Name Cardholder First Initial   Amount  \
# 0                     Mason                        C      890
# 1                     Mason                        C   368.96
# 2                    Massey                        J   165.82
# 3                    Massey                        T    96.39
# 4             Mauro-Herrera                        M   125.96
# ...                     ...                      ...      ...
# 442453           Cardholder                        e      992
# 442454           Cardholder                        e     2415
# 442455           Cardholder                        e    177.5
# 442456           Cardholder                        e    32457
# 442457           Cardholder                        e  4714.07
#
#                            Vendor        Transaction Date  \
# 0                           NACAS  07/30/2013 12:00:00 AM
# 1                  SHERATON HOTEL  07/30/2013 12:00:00 AM
# 2                  SEARS.COM 9300  07/29/2013 12:00:00 AM
# 3                  WAL-MART #0137  07/30/2013 12:00:00 AM
# 4                  STAPLES DIRECT  07/30/2013 12:00:00 AM
# ...                           ...                     ...
# 442453        TOTAL VALVE SYSTEMS  06/20/2014 12:00:00 AM
# 442454  PRYOR WASTE & RECYCLING L  06/20/2014 12:00:00 AM
# 442455  ACCURATE ENVIROMENTAL LAB  06/20/2014 12:00:00 AM
# 442456        RED BUD SERVICE INC  06/19/2014 12:00:00 AM
# 442457      WARRENCAT CREDIT DEPT  06/20/2014 12:00:00 AM
#
#                    Posted Date  \
# 0       07/31/2013 12:00:00 AM
# 1       07/31/2013 12:00:00 AM
# 2       07/31/2013 12:00:00 AM
# 3       07/31/2013 12:00:00 AM
# 4       07/31/2013 12:00:00 AM
# ...                        ...
# 442453  06/23/2014 12:00:00 AM
# 442454  06/23/2014 12:00:00 AM
# 442455  06/23/2014 12:00:00 AM
# 442456  06/23/2014 12:00:00 AM
# 442457  06/23/2014 12:00:00 AM
#
#                              Merchant Category Code (MCC)
# 0             CHARITABLE AND SOCIAL SERVICE ORGANIZATIONS
# 1                                                SHERATON
# 2       DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 3                         GROCERY STORES,AND SUPERMARKETS
# 4       STATIONERY, OFFICE SUPPLIES, PRINTING AND WRIT...
# ...                                                   ...
# 442453                    HARDWARE EQUIPMENT AND SUPPLIES
# 442454            UTILITIES - ELECTRIC,GAS,WATER,SANITARY
# 442455         BUSINESS SERVICES NOT ELSEWHERE CLASSIFIED
# 442456     PROFESSIONAL SERVICES NOT ELSEWHERE CLASSIFIED
# 442457          MISCELLANEOUS AND SPECIALTY RETAIL STORES
#
# [442183 rows x 10 columns]

# %% [markdown]
# ## Exploration
#
# Let's take a look at the values that are present in the dataset and see if we can extract any valuable information just from visual analysis.

# %% [markdown]
# ### Agencies
#
# Let's start by exploring the agency names and numbers and see what we might find.
#
# In total we have 124 unique agency names. However, it seems that some names may be duplicated with some typos, because we only have 116 unique agency numbers. This is the case for example for `BD. OF EXAM. FOR LT CARE ADMIN` and `BD. OF EXAM. FOR LT CARE ADMIN.`.

# %%
df.groupby(['Agency Name']).size()
# Out:
# Agency Name
# ARDMORE HIGHER EDUCATION CENTER      59
# ATTORNEY GENERAL                   1495
# BD. OF CHEM. TEST ALCOHOL/DRUG       82
# BD. OF EXAM. FOR LT CARE ADMIN       17
# BD. OF EXAM. FOR LT CARE ADMIN.      15
#                                    ...
# WATER RESOURCES BOARD              1388
# WILL ROGERS MEMORIAL COMMISSION      48
# WORKER'S COMP. COMMISSION             1
# WORKERS COMPENSATION COURT           11
# `DEPARTMENT OF EDUCATION            924
# Length: 124, dtype: int64

# %%
df.groupby(['Agency Number']).size()
# Out:
# Agency Number
# 1000     115926
# 2000        143
# 2200         10
# 2500       5679
# 3900        170
#           ...
# 86500         1
# 87500       107
# 88000        48
# 92200      1075
# 98000     10422
# Length: 116, dtype: int64

# %%
df['Agency Name'].unique()
# Out:
# array(['OKLAHOMA STATE UNIVERSITY', 'OKLAHOMA ACCOUNTANCY BOARD',
#        'OKLAHOMA ABSTRACTORS BOARD', 'OKLAHOMA MILITARY DEPARTMENT',
#        'BOLL WEEVIL ERADICATION ORG.', 'DEPARTMENT OF AGRICULTURE',
#        'OKLA. BD. OF ARCHITECTS', 'INDIGENT DEFENSE SYSTEM',
#        'ATTORNEY GENERAL', 'STATE ARTS COUNCIL',
#        'OKLAHOMA AERONAUTICS COMMISSION', 'STATE BANKING DEPARTMENT',
#        'OFFICE OF MANAGEMENT AND ENTERPRISE SERV',
#        'TOBACCO SETTLEMENT ENDMT TRUST', 'CAPITOL IMPROVEMENT AUTHORITY',
#        'DEPARTMENT OF MINES', 'COMMISSION ON CHILDREN AND YOUTH',
#        'DEPARTMENT OF CORRECTIONS', 'ST. BD. OF CHIROPRACTIC EXAM.',
#        'UNIV.OF SCIENCE & ARTS OF OK', 'DEPARTMENT OF COMMERCE',
#        'CORPORATION COMMISSION', 'COSMETOLOGY BOARD',
#        'J. M. DAVIS ARMS & HIST. MUSEUM', 'BOARD OF DENTISTRY',
#        'DISTRICT ATTORNEYS COUNCIL', 'EASTERN OKLA. STATE COLLEGE',
#        'REDLANDS COMMUNITY COLLEGE', '`DEPARTMENT OF EDUCATION',
#        'OK. COMM. FOR TEACHER PREP.', 'STATE ELECTION BOARD',
#        'EMPLOYMENT SECURITY COMMISSION', 'DEPT. OF ENVIRONMENTAL QUALITY',
#        'ETHICS COMMISSION', 'MERIT PROTECTION COMMISSION',
#        'STATE AUDITOR AND INSPECTOR', 'GOVERNOR',
#        'PARDON AND PAROLE BOARD', 'STATE BUREAU OF INVESTIGATION',
#        'DEPARTMENT OF EMERGENCY MANAGEMEN', 'STATE FIRE MARSHAL',
#        'FIREFIGHTERS PENS. & RET. SYST.',
#        'DEPARTMENT OF WILDLIFE CONSERVATION',
#        'OFFICE OF DISABILITY CONCERNS', 'STATE DEPARTMENT OF HEALTH',
#        'BD. OF MEDICOLEGAL INVESTIGATIONS',
#        'DEPARTMENT OF TRANSPORTATION', 'OKLA. SPACE INDUSTRY DEV. AUTH.',
#        'HISTORICAL SOCIETY', 'OKLA. HORSE RACING COMM.',
#        'WORKERS COMPENSATION COURT', 'OKLAHOMA INSURANCE DEPARTMENT',
#        'COMPSOURCE OKLAHOMA', 'OFFICE OF JUVENILE AFFAIRS',
#        'DEPARTMENT OF LABOR', 'COMM. OF THE LAND OFFICE',
#        'COUNCIL ON LAW ENFC. ED. & TRNG.', 'OK. LAW ENFORCE. RET. SYSTEM',
#        'LANGSTON UNIVERSITY', 'OK. HOUSE OF REPRESENTATIVES',
#        'DEPARTMENT OF LIBRARIES', 'OKLAHOMA LOTTERY COMMISSION',
#        'MARGINALLY PROD. OIL & GAS WELLS',
#        'BD. OF MED. LICENSURE & SUPV.',
#        'MENTAL HEALTH AND SUBSTANCE ABUSE SERV.',
#        'OKLA. BUREAU OF NARCOTICS AND DANGEROUS',
#        'N. E. OKLA. A & M COLLEGE', 'BD. OF EXAM. FOR LT CARE ADMIN',
#        'OKLA. BOARD OF NURSING', 'OK. PUBLIC EMPLOYEES RET. SYS.',
#        'OKLA. PANHANDLE STATE UNIV.', 'ROSE STATE COLEGE',
#        'POLICE PENSION & RET. SYSTEM', 'STATE PHARMACY BOARD',
#        'DEPARTMENT OF TOURISM AND RECREATION', 'SCENIC RIVERS COMMISSION',
#        'PROF. ENGI. & LAND SURVEYORS', 'STATE BOND ADVISOR',
#        'DEPARTMENT OF PUBLIC SAFETY', 'OKLA. REAL ESTATE COMM.',
#        'REGENTS FOR HIGHER EDUCATION', 'ARDMORE HIGHER EDUCATION CENTER',
#        'REGIONAL UNIVERSITY SYSTEM OF OKLAHOMA',
#        'PHYSICIAN MANPOWER TRNG. COMM.', 'SECRETARY OF STATE',
#        'OK. SCHOOL OF SCIENCE & MATH.',
#        'SPEECH-LANGUAGE PATHOLOGY & AUDIOLOGY',
#        'OKLA. CITY COMMUNITY COLLEGE', 'COMM. ON CONSUMER CREDIT',
#        'CONSERVATION COMMISSION', 'DEPARTMENT OF VETERANS AFFAIRS',
#        'S. W. OKLA. ST. UNIV.', 'J.D. MCCARTY CENTER', 'SUPREME COURT',
#        'OKLAHOMA TAX COMMISSION', 'TEACHERS RETIREMENT SYSTEM',
#        'STATE TREASURER', 'TULSA COMMUNITY COLLEGE',
#        'UNIVERSITY OF OKLAHOMA', 'UNIV. OF OKLA. HEALTH SCIENCES CENTER',
#        'BD. OF CHEM. TEST ALCOHOL/DRUG', 'BD. OF VETERINARY MED. EXAM.',
#        'OKLA. CAREER AND TECHNOLOGY EDUCATION',
#        'DEPARTMENT OF REHABILITATION SERVICES', 'HEALTH CARE AUTHORITY',
#        'EMPLOYEES BENEFITS DEPARTMENT', 'DEPARTMENT OF HUMAN SERVICES',
#        'WATER RESOURCES BOARD', 'OKLAHOMA WHEAT COMMISSION',
#        'WILL ROGERS MEMORIAL COMMISSION',
#        'OKLAHOMA HOUSING FINANCE AGENCY', 'GRAND RIVER DAM AUTH.',
#        'DEPARTMENT OF AGRICULTURE, FOOD, ANF FOR',
#        'OKLAHOMA ST.BOARD OF DENTISTRY', 'DEPARTMENT OF EDUCATION',
#        'DEPARTMENT OF EMERGENCY MANAGEMENT',
#        'OFFICE OF THE CHIEF MEDICAL EXAMINER',
#        'MULTIPLE INJURY TRUST FUND', 'BD. OF EXAM. FOR LT CARE ADMIN.',
#        'UNIVERSITY CENTER OF SOUTHERN OKLAHOMA',
#        "WORKER'S COMP. COMMISSION", 'ST BD OF COSMETOLOGY AND BARBERING',
#        'OFFICE OF EDUC. QUALITY & ACCOUNTABILITY',
#        'BD. OF PRIV. VOCATIONAL SCHOOLS'], dtype=object)

# %%
discrepant_names_df = pd.DataFrame(df.groupby(['Agency Number'])['Agency Name'].unique()).reset_index()
discrepant_names = discrepant_names_df[discrepant_names_df['Agency Name'].apply(lambda x: len(x) > 1)]
discrepant_names
# Out:
#     Agency Number                                        Agency Name
# 5            4000  [DEPARTMENT OF AGRICULTURE, DEPARTMENT OF AGRI...
# 22          19000  [COSMETOLOGY BOARD, ST BD OF COSMETOLOGY AND B...
# 24          21500  [BOARD OF DENTISTRY, OKLAHOMA ST.BOARD OF DENT...
# 28          26500  [`DEPARTMENT OF EDUCATION, DEPARTMENT OF EDUCA...
# 40          30900  [DEPARTMENT OF EMERGENCY MANAGEMEN, DEPARTMENT...
# 46          34200  [BD. OF MEDICOLEGAL INVESTIGATIONS, OFFICE OF ...
# 69          50900  [BD. OF EXAM. FOR LT CARE ADMIN, BD. OF EXAM. ...
# 84          60600  [ARDMORE HIGHER EDUCATION CENTER, UNIVERSITY C...

# %%
for name in discrepant_names['Agency Name']:
    print(name)
# Out:
# ['DEPARTMENT OF AGRICULTURE' 'DEPARTMENT OF AGRICULTURE, FOOD, ANF FOR']
# ['COSMETOLOGY BOARD' 'ST BD OF COSMETOLOGY AND BARBERING']
# ['BOARD OF DENTISTRY' 'OKLAHOMA ST.BOARD OF DENTISTRY']
# ['`DEPARTMENT OF EDUCATION' 'DEPARTMENT OF EDUCATION']
# ['DEPARTMENT OF EMERGENCY MANAGEMEN' 'DEPARTMENT OF EMERGENCY MANAGEMENT']
# ['BD. OF MEDICOLEGAL INVESTIGATIONS'
#  'OFFICE OF THE CHIEF MEDICAL EXAMINER']
# ['BD. OF EXAM. FOR LT CARE ADMIN' 'BD. OF EXAM. FOR LT CARE ADMIN.']
# ['ARDMORE HIGHER EDUCATION CENTER'
#  'UNIVERSITY CENTER OF SOUTHERN OKLAHOMA']

# %%
discrepant_names['Correct Name'] = [
    'DEPARTMENT OF AGRICULTURE',
    'ST BD OF COSMETOLOGY AND BARBERING',
    'OKLAHOMA ST. BOARD OF DENTISTRY',
    'DEPARTMENT OF EDUCATION',
    'DEPARTMENT OF EMERGENCY MANAGEMENT',
    'BD. OF MEDICOLEGAL INVESTIGATIONS',
    'BD. OF EXAM. FOR LT CARE ADMIN',
    'UNIVERSITY CENTER OF SOUTHERN OKLAHOMA']
discrepant_names
# Out:
# /tmp/ipykernel_39/4113294756.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   discrepant_names['Correct Name'] = [
#     Agency Number                                        Agency Name  \
# 5            4000  [DEPARTMENT OF AGRICULTURE, DEPARTMENT OF AGRI...
# 22          19000  [COSMETOLOGY BOARD, ST BD OF COSMETOLOGY AND B...
# 24          21500  [BOARD OF DENTISTRY, OKLAHOMA ST.BOARD OF DENT...
# 28          26500  [`DEPARTMENT OF EDUCATION, DEPARTMENT OF EDUCA...
# 40          30900  [DEPARTMENT OF EMERGENCY MANAGEMEN, DEPARTMENT...
# 46          34200  [BD. OF MEDICOLEGAL INVESTIGATIONS, OFFICE OF ...
# 69          50900  [BD. OF EXAM. FOR LT CARE ADMIN, BD. OF EXAM. ...
# 84          60600  [ARDMORE HIGHER EDUCATION CENTER, UNIVERSITY C...
#
#                               Correct Name
# 5                DEPARTMENT OF AGRICULTURE
# 22      ST BD OF COSMETOLOGY AND BARBERING
# 24         OKLAHOMA ST. BOARD OF DENTISTRY
# 28                 DEPARTMENT OF EDUCATION
# 40      DEPARTMENT OF EMERGENCY MANAGEMENT
# 46       BD. OF MEDICOLEGAL INVESTIGATIONS
# 69          BD. OF EXAM. FOR LT CARE ADMIN
# 84  UNIVERSITY CENTER OF SOUTHERN OKLAHOMA

# %%
for agency_number in discrepant_names['Agency Number']:
    correct_name = discrepant_names.loc[discrepant_names['Agency Number'] == agency_number, 'Correct Name'].values[0]
    df.loc[df['Agency Number'] == agency_number, 'Agency Name'] = correct_name

# %%
df[df['Agency Number'] == 4000]['Agency Name'].unique()
# Out:
# array(['DEPARTMENT OF AGRICULTURE'], dtype=object)

# %%
discrepant_names_df = pd.DataFrame(df.groupby(['Agency Number'])['Agency Name'].unique()).reset_index()
discrepant_names = discrepant_names_df[discrepant_names_df['Agency Name'].apply(lambda x: len(x) > 1)]
discrepant_names
# Out:
# Empty DataFrame
# Columns: [Agency Number, Agency Name]
# Index: []

# %% [markdown]
# Cool, now we have a clean Agency Name field. Let's explore some more their values.

# %%
df.head()
# Out:
#    Year-Month  Agency Number                Agency Name Cardholder Last Name  \
# 0      201307           1000  OKLAHOMA STATE UNIVERSITY                Mason
# 1      201307           1000  OKLAHOMA STATE UNIVERSITY                Mason
# 2      201307           1000  OKLAHOMA STATE UNIVERSITY               Massey
# 3      201307           1000  OKLAHOMA STATE UNIVERSITY               Massey
# 4      201307           1000  OKLAHOMA STATE UNIVERSITY        Mauro-Herrera
#
#   Cardholder First Initial  Amount          Vendor        Transaction Date  \
# 0                        C     890           NACAS  07/30/2013 12:00:00 AM
# 1                        C  368.96  SHERATON HOTEL  07/30/2013 12:00:00 AM
# 2                        J  165.82  SEARS.COM 9300  07/29/2013 12:00:00 AM
# 3                        T   96.39  WAL-MART #0137  07/30/2013 12:00:00 AM
# 4                        M  125.96  STAPLES DIRECT  07/30/2013 12:00:00 AM
#
#               Posted Date                       Merchant Category Code (MCC)
# 0  07/31/2013 12:00:00 AM        CHARITABLE AND SOCIAL SERVICE ORGANIZATIONS
# 1  07/31/2013 12:00:00 AM                                           SHERATON
# 2  07/31/2013 12:00:00 AM  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 3  07/31/2013 12:00:00 AM                    GROCERY STORES,AND SUPERMARKETS
# 4  07/31/2013 12:00:00 AM  STATIONERY, OFFICE SUPPLIES, PRINTING AND WRIT...

# %%
len(df)
# Out:
# 442183

# %%
import matplotlib.pyplot as plt
agency_counts = df.groupby("Agency Name").size().sort_values(ascending=False)
agency_counts.plot(kind='bar', figsize=(20, 10))
plt.xlabel('Agency Name')
plt.ylabel('Number of Transactions')
plt.title('Number of Transactions by Agency Name')
plt.show()

# %%
total_transactions = len(df)
agency_counts_percentage = (agency_counts / total_transactions) * 100

agency_counts_percentage.plot(kind='bar', figsize=(20, 10))
plt.xlabel('Agency Name')
plt.ylabel('Percentage of Transactions')
plt.title('Percentage of Transactions by Agency Name')
plt.show()

# %%
sum(agency_counts_percentage.values[0:3])
# Out:
# 56.57906341944399

# %%
sum(agency_counts_percentage.values[0:24])
# Out:
# 90.56612307574014

# %% [markdown]
# Seems that we have a pretty top-heavy dataset, in which the top 3 agencies account for over 55% of the transactions. The top 24 agencies account for over 90% of the transactions. I think we may also have to analyze if not only the *number* of transactions is skewed, but also the total transaction *volume*. Let's take a look at the `amount` field first and then merge these results.

# %% [markdown]
# ### Amount
#
# The amount field wasn't properly parsed, let's transform it all into float first.

# %%
import numpy as np
df['Amount'] = df['Amount'].astype(np.float32)

# %%
df['Amount'].describe()
# Out:
# count    4.421830e+05
# mean     4.251841e+02
# std      5.268139e+03
# min     -4.286304e+04
# 25%      3.093000e+01
# 50%      1.049400e+02
# 75%      3.450000e+02
# max      1.903858e+06
# Name: Amount, dtype: float64

# %%
df[df['Amount'] < 0]
# Out:
#         Year-Month  Agency Number                Agency Name  \
# 25          201307           1000  OKLAHOMA STATE UNIVERSITY
# 114         201307           1000  OKLAHOMA STATE UNIVERSITY
# 148         201307           1000  OKLAHOMA STATE UNIVERSITY
# 178         201307           1000  OKLAHOMA STATE UNIVERSITY
# 185         201307           1000  OKLAHOMA STATE UNIVERSITY
# ...            ...            ...                        ...
# 442378      201406          98000      GRAND RIVER DAM AUTH.
# 442386      201406          98000      GRAND RIVER DAM AUTH.
# 442392      201406          98000      GRAND RIVER DAM AUTH.
# 442404      201406          98000      GRAND RIVER DAM AUTH.
# 442425      201406          98000      GRAND RIVER DAM AUTH.
#
#        Cardholder Last Name Cardholder First Initial       Amount  \
# 25                     Foye                        S   -30.000000
# 114               Henderson                        K  -340.000000
# 148                   Flock                        S  -258.000000
# 178                  Arthur                        H  -167.199997
# 185                    Page                        M   -39.259998
# ...                     ...                      ...          ...
# 442378               Prince                        S    -9.960000
# 442386               Stroup                        P  -136.000000
# 442392            Yarbrough                        K   -25.980000
# 442404           Cardholder                        e  -136.000000
# 442425              Jaggars                        J -1395.000000
#
#                            Vendor        Transaction Date  \
# 25                AFFYMETRIX, INC  07/26/2013 12:00:00 AM
# 114       INTERWRX (INTERWRX.COM)  07/26/2013 12:00:00 AM
# 148           THE HOME DEPOT 3904  07/26/2013 12:00:00 AM
# 178     GRAND VISTA HOTEL SIMI VA  07/29/2013 12:00:00 AM
# 185                    Amazon.com  07/30/2013 12:00:00 AM
# ...                           ...                     ...
# 442378    BEST WESTERN CIMARRONHT  06/20/2014 12:00:00 AM
# 442386               MATHESON-308  06/20/2014 12:00:00 AM
# 442392       TRACTOR SUPPLY #1102  06/20/2014 12:00:00 AM
# 442404               MATHESON-308  06/19/2014 12:00:00 AM
# 442425                   ESRI INC  06/17/2014 12:00:00 AM
#
#                    Posted Date  \
# 25      07/29/2013 12:00:00 AM
# 114     07/29/2013 12:00:00 AM
# 148     07/29/2013 12:00:00 AM
# 178     07/30/2013 12:00:00 AM
# 185     07/31/2013 12:00:00 AM
# ...                        ...
# 442378  06/23/2014 12:00:00 AM
# 442386  06/23/2014 12:00:00 AM
# 442392  06/23/2014 12:00:00 AM
# 442404  06/20/2014 12:00:00 AM
# 442425  06/19/2014 12:00:00 AM
#
#                              Merchant Category Code (MCC)
# 25      DENTAL/LABORATORY/MEDICAL/OPHTHALMIC HOSP EQIP...
# 114       TELECOMMUNICATION EQUIPMENT AND TELEPHONE SALES
# 148                          HOME SUPPLY WAREHOUSE STORES
# 178                    LODGING--HOTELS,MOTELS,AND RESORTS
# 185                                           BOOK STORES
# ...                                                   ...
# 442378                 LODGING--HOTELS,MOTELS,AND RESORTS
# 442386  CHEMICALS AND ALLIED PRODUCTS NOT ELSEWHERE CL...
# 442392  MISC. AUTOMOTIVE,AIRCRAFT,AND FARM EQUIPMENT D...
# 442404  CHEMICALS AND ALLIED PRODUCTS NOT ELSEWHERE CL...
# 442425                           COMPUTER SOFTWARE STORES
#
# [14531 rows x 10 columns]

# %%
df[(df['Amount'] < 0) & (df['Agency Number'] == 98000) & (df['Vendor'].str.contains('ESRI'))]
# Out:
#         Year-Month  Agency Number            Agency Name Cardholder Last Name  \
# 442425      201406          98000  GRAND RIVER DAM AUTH.              Jaggars
#
#        Cardholder First Initial  Amount    Vendor        Transaction Date  \
# 442425                        J -1395.0  ESRI INC  06/17/2014 12:00:00 AM
#
#                    Posted Date Merchant Category Code (MCC)
# 442425  06/19/2014 12:00:00 AM     COMPUTER SOFTWARE STORES

# %%
df[(df['Amount'] > 0) & (df['Agency Number'] == 98000) & (df['Vendor'].str.contains('ESRI'))]
# Out:
#         Year-Month  Agency Number            Agency Name Cardholder Last Name  \
# 366135      201403          98000  GRAND RIVER DAM AUTH.              Jaggars
# 366479      201403          98000  GRAND RIVER DAM AUTH.               Hunter
#
#        Cardholder First Initial  Amount    Vendor        Transaction Date  \
# 366135                        J  1395.0  ESRI INC  03/28/2014 12:00:00 AM
# 366479                        G  4400.0  ESRI INC  03/13/2014 12:00:00 AM
#
#                    Posted Date Merchant Category Code (MCC)
# 366135  03/31/2014 12:00:00 AM     COMPUTER SOFTWARE STORES
# 366479  03/14/2014 12:00:00 AM     COMPUTER SOFTWARE STORES

# %% [markdown]
# Looks like we have negative numbers indicating maybe reverse transactions (or maybe refunds?). We have two options here:
#
# 1. Assume these values were actually human error and they actually meant a positive amount (they may have mixed up "dollars spent" with "amount").
# 2. Pass all these negative values into positive and set a "Refund" flag.
#
# Looking through similar datasets on the internet, I found the the Oklahoma goverment's purchase card information (https://data.ok.gov/dataset), which seems to be source of the original dataset. Taking a look at examples from other fiscal years (omitted here), it seems that these negative values persist on all datasets. Therefore, for the sake of completness, I'll choose option 2 and assume these are refund values.

# %%
df['Refund'] = df['Amount'] < 0
df['Amount'] = df['Amount'].abs()

# %%
df['Amount'].describe()
# Out:
# count    4.421830e+05
# mean     4.412978e+02
# std      5.266813e+03
# min      1.000000e-02
# 25%      3.499000e+01
# 50%      1.109200e+02
# 75%      3.543250e+02
# max      1.903858e+06
# Name: Amount, dtype: float64

# %%
mean_total_transaction_volume = df.groupby('Agency Name')['Amount'].mean()
non_refunded_df = df[df['Refund'] == False]

# %% [markdown]
# There seems to be something wrong with that max value, there may be an outlier.

# %%
mean_total_transaction_volume.plot(kind='bar', figsize=(20, 10))
plt.xlabel('Agency Name')
plt.ylabel('Mean Amount')
plt.title('Mean Amount by Agency Name')
plt.show()

# %%
df[df['Agency Name'].str.contains('EMPLOYEES BENEFITS')]
# Out:
#         Year-Month  Agency Number                    Agency Name  \
# 246477      201307          81500  EMPLOYEES BENEFITS DEPARTMENT
# 246478      201307          81500  EMPLOYEES BENEFITS DEPARTMENT
#
#        Cardholder Last Name Cardholder First Initial         Amount  \
# 246477                81500                        8  343148.500000
# 246478                81500                        8      90.720001
#
#                     Vendor        Transaction Date             Posted Date  \
# 246477  PAYMENT ADJUSTMENT  06/13/2013 12:00:00 AM  07/03/2013 12:00:00 AM
# 246478          CBR MAN CK  07/08/2013 12:00:00 AM  07/09/2013 12:00:00 AM
#
#        Merchant Category Code (MCC)  Refund
# 246477                   OTHER FEES   False
# 246478                   OTHER FEES   False

# %% [markdown]
# Yep, it seems that the EMPLOYEES BENEFITS DEPARTMENTS made only 2 purchases, one of them being a payment adjustment in a very high amount, which makes the mean be pretty high. Let's plot without this outlier.

# %%
mean_total_transaction_volume_no_outliers = df[~df['Agency Name'].str.contains('EMPLOYEES BENEFITS')].groupby('Agency Name')['Amount'].mean()
mean_total_transaction_volume_no_outliers.plot(kind='bar', figsize=(20, 10))
plt.xlabel('Agency Name')
plt.ylabel('Mean Amount')
plt.title('Mean Amount by Agency Name')
plt.show()

# %% [markdown]
# Probably a good idea to normalize these values when modelling.

# %% [markdown]
# ### Vendors
#
# Let's repeat the same analysis we did for the Agencies but now for the Vendors.

# %%
len(df['Vendor'].unique())
# Out:
# 86727

# %% [markdown]
# That's a lot of vendors. There may be duplicated vendors due to different stores of the same company.

# %%
df['Vendor'].unique()
# Out:
# array(['NACAS', 'SHERATON HOTEL', 'SEARS.COM 9300', ...,
#        'ACME TOOLS #110', 'W.S. DARLEY & CO.',
#        'GENERATOR AND MOTOR SERVI'], dtype=object)

# %%
df[df['Vendor'].str.contains("SEARS")][['Vendor', 'Merchant Category Code (MCC)']].head(50)
# Out:
#                      Vendor                       Merchant Category Code (MCC)
# 2            SEARS.COM 9300  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 1870    SEARS HOMETOWN 3647                                  DEPARTMENT STORES
# 2926   SEARS ROEBUCK   7931  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 3112    SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 6046      GENE SEARS SUPPLY                              SPORTING GOODS STORES
# 7947   SEARS ROEBUCK   7931  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 8106     SEARS ROEBUCK 7711  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 10419   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 11438    SEARS ROEBUCK 7711  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 12699   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 13143   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 13447   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 13481   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 14197   SEARS HOMETOWN 3647                                  DEPARTMENT STORES
# 14690   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 14742   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 16431        SEARS.COM 9300  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 16841   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 20705   SEARS HOMETOWN 3647                                  DEPARTMENT STORES
# 23631   SEARS HOMETOWN 6987                                  DEPARTMENT STORES
# 23869   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 24400        SEARS.COM 9301  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 28426   SEARS HOMETOWN 3647                                  DEPARTMENT STORES
# 36963     GENE SEARS SUPPLY                              SPORTING GOODS STORES
# 37768   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 38460   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 39166   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 41708     GENE SEARS SUPPLY                              SPORTING GOODS STORES
# 41823   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 48176   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 50555        SEARS.COM 9301  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 55814        SEARS.COM 9301  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 57567   SEARS HOMETOWN 3647                                  DEPARTMENT STORES
# 59832        SEARS.COM 9301  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 61367   SEARS HOMETOWN 3647                                  DEPARTMENT STORES
# 62300   SEARS HOMETOWN 3036                                  DEPARTMENT STORES
# 64516        SEARS.COM 9301  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 64887        SEARS.COM 9301  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 64888        SEARS.COM 9301  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 67797   SEARS HOMETOWN 3722                                  DEPARTMENT STORES
# 69565  SEARS ROEBUCK   2311                                  DEPARTMENT STORES
# 71585  SEARS ROEBUCK   2311                                  DEPARTMENT STORES
# 78738  SEARS ROEBUCK   2291                                  DEPARTMENT STORES
# 79245  SEARS ROEBUCK   7923  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...
# 79608  SEARS ROEBUCK   2381                                  DEPARTMENT STORES
# 79610  SEARS ROEBUCK   2381                                  DEPARTMENT STORES
# 79611  SEARS ROEBUCK   2381                                  DEPARTMENT STORES
# 79612  SEARS ROEBUCK   2381                                  DEPARTMENT STORES
# 79643   SEARS HOMETOWN 3742                                  DEPARTMENT STORES
# 79692  SEARS ROEBUCK   2381                                  DEPARTMENT STORES

# %%
df[df['Vendor'].str.contains("ACME")]['Vendor'].unique()
# Out:
# array(['ACME FENCE OF OKLAHOMA C', 'ACME BRICK #261', 'IDN ACME INC',
#        'ACME REESE AIR COND', 'ACME BRICK #230', 'ACME PRODUCTS COMPANY',
#        'ACME OYSTER HOUSE', 'ACME JANITOR & CHEMICAL S', 'IACME',
#        'ACME BRICK #260', 'ACME TOOLS #110'], dtype=object)

# %% [markdown]
# Yep, there are a lot of duplicated vendors. However, parsing this with regex may not be the best idea, as we kinda want to preserve the store number information for modelling. I believe text embeddings and cosine similarity may be enough to extract relational features from these cases. Let's keep it like this.

# %%
df.head()
# Out:
#    Year-Month  Agency Number                Agency Name Cardholder Last Name  \
# 0      201307           1000  OKLAHOMA STATE UNIVERSITY                Mason
# 1      201307           1000  OKLAHOMA STATE UNIVERSITY                Mason
# 2      201307           1000  OKLAHOMA STATE UNIVERSITY               Massey
# 3      201307           1000  OKLAHOMA STATE UNIVERSITY               Massey
# 4      201307           1000  OKLAHOMA STATE UNIVERSITY        Mauro-Herrera
#
#   Cardholder First Initial      Amount          Vendor  \
# 0                        C  890.000000           NACAS
# 1                        C  368.959991  SHERATON HOTEL
# 2                        J  165.820007  SEARS.COM 9300
# 3                        T   96.389999  WAL-MART #0137
# 4                        M  125.959999  STAPLES DIRECT
#
#          Transaction Date             Posted Date  \
# 0  07/30/2013 12:00:00 AM  07/31/2013 12:00:00 AM
# 1  07/30/2013 12:00:00 AM  07/31/2013 12:00:00 AM
# 2  07/29/2013 12:00:00 AM  07/31/2013 12:00:00 AM
# 3  07/30/2013 12:00:00 AM  07/31/2013 12:00:00 AM
# 4  07/30/2013 12:00:00 AM  07/31/2013 12:00:00 AM
#
#                         Merchant Category Code (MCC)  Refund
# 0        CHARITABLE AND SOCIAL SERVICE ORGANIZATIONS   False
# 1                                           SHERATON   False
# 2  DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...   False
# 3                    GROCERY STORES,AND SUPERMARKETS   False
# 4  STATIONERY, OFFICE SUPPLIES, PRINTING AND WRIT...   False

# %% [markdown]
# ### Transaction Date

# %%
df.groupby("Transaction Date").size()
# Out:
# Transaction Date
# 01/01/2014 12:00:00 AM     190
# 01/02/2014 12:00:00 AM     907
# 01/03/2014 12:00:00 AM    1179
# 01/04/2014 12:00:00 AM     384
# 01/05/2014 12:00:00 AM     144
#                           ...
# 12/27/2013 12:00:00 AM     523
# 12/28/2013 12:00:00 AM     183
# 12/29/2013 12:00:00 AM      62
# 12/30/2013 12:00:00 AM     540
# 12/31/2013 12:00:00 AM     589
# Length: 392, dtype: int64

# %%
df["Transaction Date"] = pd.to_datetime(df["Transaction Date"])

# %%
df
# Out:
#         Year-Month  Agency Number                Agency Name  \
# 0           201307           1000  OKLAHOMA STATE UNIVERSITY
# 1           201307           1000  OKLAHOMA STATE UNIVERSITY
# 2           201307           1000  OKLAHOMA STATE UNIVERSITY
# 3           201307           1000  OKLAHOMA STATE UNIVERSITY
# 4           201307           1000  OKLAHOMA STATE UNIVERSITY
# ...            ...            ...                        ...
# 442453      201406          98000      GRAND RIVER DAM AUTH.
# 442454      201406          98000      GRAND RIVER DAM AUTH.
# 442455      201406          98000      GRAND RIVER DAM AUTH.
# 442456      201406          98000      GRAND RIVER DAM AUTH.
# 442457      201406          98000      GRAND RIVER DAM AUTH.
#
#        Cardholder Last Name Cardholder First Initial        Amount  \
# 0                     Mason                        C    890.000000
# 1                     Mason                        C    368.959991
# 2                    Massey                        J    165.820007
# 3                    Massey                        T     96.389999
# 4             Mauro-Herrera                        M    125.959999
# ...                     ...                      ...           ...
# 442453           Cardholder                        e    992.000000
# 442454           Cardholder                        e   2415.000000
# 442455           Cardholder                        e    177.500000
# 442456           Cardholder                        e  32457.000000
# 442457           Cardholder                        e   4714.069824
#
#                            Vendor Transaction Date             Posted Date  \
# 0                           NACAS       2013-07-30  07/31/2013 12:00:00 AM
# 1                  SHERATON HOTEL       2013-07-30  07/31/2013 12:00:00 AM
# 2                  SEARS.COM 9300       2013-07-29  07/31/2013 12:00:00 AM
# 3                  WAL-MART #0137       2013-07-30  07/31/2013 12:00:00 AM
# 4                  STAPLES DIRECT       2013-07-30  07/31/2013 12:00:00 AM
# ...                           ...              ...                     ...
# 442453        TOTAL VALVE SYSTEMS       2014-06-20  06/23/2014 12:00:00 AM
# 442454  PRYOR WASTE & RECYCLING L       2014-06-20  06/23/2014 12:00:00 AM
# 442455  ACCURATE ENVIROMENTAL LAB       2014-06-20  06/23/2014 12:00:00 AM
# 442456        RED BUD SERVICE INC       2014-06-19  06/23/2014 12:00:00 AM
# 442457      WARRENCAT CREDIT DEPT       2014-06-20  06/23/2014 12:00:00 AM
#
#                              Merchant Category Code (MCC)  Refund
# 0             CHARITABLE AND SOCIAL SERVICE ORGANIZATIONS   False
# 1                                                SHERATON   False
# 2       DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...   False
# 3                         GROCERY STORES,AND SUPERMARKETS   False
# 4       STATIONERY, OFFICE SUPPLIES, PRINTING AND WRIT...   False
# ...                                                   ...     ...
# 442453                    HARDWARE EQUIPMENT AND SUPPLIES   False
# 442454            UTILITIES - ELECTRIC,GAS,WATER,SANITARY   False
# 442455         BUSINESS SERVICES NOT ELSEWHERE CLASSIFIED   False
# 442456     PROFESSIONAL SERVICES NOT ELSEWHERE CLASSIFIED   False
# 442457          MISCELLANEOUS AND SPECIALTY RETAIL STORES   False
#
# [442183 rows x 11 columns]

# %%
df.sort_values(by="Transaction Date", ascending=True).groupby("Transaction Date").size().plot(kind='line', figsize=(20, 10))
# Out:
# <AxesSubplot: xlabel='Transaction Date'>

# %% [markdown]
# The transaction date seems to follow a logical pattern, being small on weekends and holidays, but maintaining a somewhat steady value throughout the rest of the days.

# %%
df.sort_values(by="Transaction Date", ascending=True).groupby("Transaction Date").sum("Amount")["Amount"].plot(kind='line', figsize=(20, 10), title="Total Transaction Volume by Date")
# Out:
# <AxesSubplot: title={'center': 'Total Transaction Volume by Date'}, xlabel='Transaction Date'>

# %%
df['Posted Date'] = pd.to_datetime(df['Posted Date'])
df
# Out:
#         Year-Month  Agency Number                Agency Name  \
# 0           201307           1000  OKLAHOMA STATE UNIVERSITY
# 1           201307           1000  OKLAHOMA STATE UNIVERSITY
# 2           201307           1000  OKLAHOMA STATE UNIVERSITY
# 3           201307           1000  OKLAHOMA STATE UNIVERSITY
# 4           201307           1000  OKLAHOMA STATE UNIVERSITY
# ...            ...            ...                        ...
# 442453      201406          98000      GRAND RIVER DAM AUTH.
# 442454      201406          98000      GRAND RIVER DAM AUTH.
# 442455      201406          98000      GRAND RIVER DAM AUTH.
# 442456      201406          98000      GRAND RIVER DAM AUTH.
# 442457      201406          98000      GRAND RIVER DAM AUTH.
#
#        Cardholder Last Name Cardholder First Initial        Amount  \
# 0                     Mason                        C    890.000000
# 1                     Mason                        C    368.959991
# 2                    Massey                        J    165.820007
# 3                    Massey                        T     96.389999
# 4             Mauro-Herrera                        M    125.959999
# ...                     ...                      ...           ...
# 442453           Cardholder                        e    992.000000
# 442454           Cardholder                        e   2415.000000
# 442455           Cardholder                        e    177.500000
# 442456           Cardholder                        e  32457.000000
# 442457           Cardholder                        e   4714.069824
#
#                            Vendor Transaction Date Posted Date  \
# 0                           NACAS       2013-07-30  2013-07-31
# 1                  SHERATON HOTEL       2013-07-30  2013-07-31
# 2                  SEARS.COM 9300       2013-07-29  2013-07-31
# 3                  WAL-MART #0137       2013-07-30  2013-07-31
# 4                  STAPLES DIRECT       2013-07-30  2013-07-31
# ...                           ...              ...         ...
# 442453        TOTAL VALVE SYSTEMS       2014-06-20  2014-06-23
# 442454  PRYOR WASTE & RECYCLING L       2014-06-20  2014-06-23
# 442455  ACCURATE ENVIROMENTAL LAB       2014-06-20  2014-06-23
# 442456        RED BUD SERVICE INC       2014-06-19  2014-06-23
# 442457      WARRENCAT CREDIT DEPT       2014-06-20  2014-06-23
#
#                              Merchant Category Code (MCC)  Refund
# 0             CHARITABLE AND SOCIAL SERVICE ORGANIZATIONS   False
# 1                                                SHERATON   False
# 2       DIRCT MARKETING/DIRCT MARKETERS--NOT ELSEWHERE...   False
# 3                         GROCERY STORES,AND SUPERMARKETS   False
# 4       STATIONERY, OFFICE SUPPLIES, PRINTING AND WRIT...   False
# ...                                                   ...     ...
# 442453                    HARDWARE EQUIPMENT AND SUPPLIES   False
# 442454            UTILITIES - ELECTRIC,GAS,WATER,SANITARY   False
# 442455         BUSINESS SERVICES NOT ELSEWHERE CLASSIFIED   False
# 442456     PROFESSIONAL SERVICES NOT ELSEWHERE CLASSIFIED   False
# 442457          MISCELLANEOUS AND SPECIALTY RETAIL STORES   False
#
# [442183 rows x 11 columns]

# %%
df.to_csv('clean_1_dataset.csv')
